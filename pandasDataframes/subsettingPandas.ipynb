# %%
import pandas as pd

# %%
data = pd.read_csv('./datasets/big_mart_sales.csv')

# %%
# index of dataframe
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# CHANGE THE INDEX OF DATAFRAME

# %%
import random
rndList = [random.randint(1,8523) for i in range(8523)]

# %%
rndList
# Out:
# [7281,
#  518,
#  8266,
#  123,
#  1580,
#  8068,
#  398,
#  7007,
#  2580,
#  6471,
#  7921,
#  8016,
#  4425,
#  1840,
#  2680,
#  5965,
#  6487,
#  5698,
#  2670,
#  7209,
#  7668,
#  4,
#  1014,
#  2037,
#  2633,
#  4683,
#  6807,
#  1722,
#  4299,
#  5236,
#  4993,
#  8390,
#  9,
#  1712,
#  5736,
#  6829,
#  3555,
#  2328,
#  2155,
#  2917,
#  6916,
#  1745,
#  5196,
#  5084,
#  3965,
#  2720,
#  296,
#  4607,
#  3234,
#  2780,
#  5134,
#  3892,
#  1799,
#  5175,
#  8434,
#  5692,
#  3637,
#  1729,
#  2840,
#  1193,
#  714,
#  6754,
#  1569,
#  7474,
#  4833,
#  3839,
#  7455,
#  717,
#  5605,
#  7676,
#  4496,
#  4113,
#  7836,
#  7939,
#  978,
#  5338,
#  6906,
#  768,
#  3650,
#  4641,
#  7507,
#  4227,
#  5943,
#  6581,
#  1974,
#  5497,
#  653,
#  8406,
#  868,
#  7040,
#  7677,
#  972,
#  582,
#  3543,
#  6253,
#  3108,
#  5562,
#  4064,
#  2842,
#  3603,
#  434,
#  6149,
#  8319,
#  7249,
#  5517,
#  3824,
#  335,
#  8438,
#  4801,
#  7245,
#  6604,
#  5225,
#  5996,
# ...

# %%
# set the index
data.index = rndList

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7281           FDA15         9.30          Low Fat         0.016047
# 518            DRC01         5.92          Regular         0.019278
# 8266           FDN15        17.50          Low Fat         0.016760
# 123            FDX07        19.20          Regular         0.000000
# 1580           NCD19         8.93          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7281                  Dairy  249.8092            OUT049
# 518             Soft Drinks   48.2692            OUT018
# 8266                   Meat  141.6180            OUT049
# 123   Fruits and Vegetables  182.0950            OUT010
# 1580              Household   53.8614            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7281                       1999      Medium               Tier 1
# 518                        2009      Medium               Tier 3
# ...

# %%
data = pd.read_csv('./datasets/big_mart_sales.csv')
updatedData = data.set_index('Outlet_Establishment_Year', drop=True, inplace=False)

# drop = True --> drop the column that's set as index : so the column is not duplicate (if True)
# inplace = True --> make change in the original dataframe

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
updatedData.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.set_index('Item_Identifier', drop=True, inplace=True)
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %%
# SUBSET THE DATA BASED ON LABEL INDEX

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# ...

# %%
# RESET THE INDEX

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# SUBSET THE DATA BASED ON THE VALUE OF COLUMN

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# ...              ...          ...              ...              ...       ...
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8447           FDS26       20.350          Low Fat         0.089975     Dairy
# 8448           FDV50       14.300          Low Fat         0.123071     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
# 8512           FDR26       20.700          Low Fat         0.042801     Dairy
#
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------SUBSETTING: POSITION BASED-----------------------------------------------------

# %%
data = pd.read_csv('./datasets/big_mart_sales.csv')
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# View top rows : will show the botom rows
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
# SELECT ROWS IN PARTICULAR RANGE

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# select range from 10:15
data[10:15]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 11           FDA03        18.50          Regular         0.045464
# 12           FDX32        15.10          Regular         0.100014
# 13           FDS46        17.60          Regular         0.047257
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 11                  Dairy  144.1102            OUT046
# 12  Fruits and Vegetables  145.4786            OUT049
# 13            Snack Foods  119.6782            OUT046
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 11                       1997       Small               Tier 1
# ...

# %%
# Select the rows by position

# %%
# Select specific rows by index
data.iloc[[1,5,2,46,14]]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1            DRC01        5.920          Regular         0.019278
# 5            FDP36       10.395          Regular         0.000000
# 2            FDN15       17.500          Low Fat         0.016760
# 46           NCP05       19.600          Low Fat         0.000000
# 14           FDF32       16.350          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 1             Soft Drinks   48.2692            OUT018
# 5            Baking Goods   51.4008            OUT018
# 2                    Meat  141.6180            OUT049
# 46     Health and Hygiene  153.3024            OUT045
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                        2009      Medium               Tier 3
# 5                        2009      Medium               Tier 3
# ...

# %%
# Select specific rows and column
data.iloc[[1,5,2,46,14], [0,3,5]]
# Out:
#    Item_Identifier  Item_Visibility  Item_MRP
# 1            DRC01         0.019278   48.2692
# 5            FDP36         0.000000   51.4008
# 2            FDN15         0.016760  141.6180
# 46           NCP05         0.000000  153.3024
# 14           FDF32         0.068024  196.4426

# %%
data.iloc[10:15:2]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 12           FDX32        15.10          Regular         0.100014
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 12  Fruits and Vegetables  145.4786            OUT049
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 12                       1999      Medium               Tier 1
# 14                       1987        High               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 10  Supermarket Type1          1516.0266
# 12  Supermarket Type1          1589.2646
# 14  Supermarket Type1          1977.4260
