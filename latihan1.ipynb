# %% [markdown]
# Using pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
# read data file
data = pd.read_csv('energy_production_data.csv')

# %%
# View data
data.head(20)
# Out:
#    timestamp  energy_production  temperature
# 0     1/1/18          19.422163    29.424069
# 1     1/2/18          11.160701    20.637519
# 2     1/3/18          93.587858    18.340461
# 3     1/4/18         179.331702    20.207211
# 4     1/5/18          90.720340    23.515103
# 5     1/6/18         239.000193    24.613277
# 6     1/7/18         320.186887    27.040780
# 7     1/8/18         340.481930    24.928800
# 8     1/9/18         464.357468    31.557603
# 9    1/10/18         484.027353    22.779882
# 10   1/11/18         479.576745    32.492579
# 11   1/12/18         589.486067    27.511986
# 12   1/13/18         551.547169    31.119039
# 13   1/14/18         512.610744    26.773816
# 14   1/15/18         616.717254    29.465460
# 15   1/16/18         728.907598    37.613968
# 16   1/17/18         768.267627    39.254032
# 17   1/18/18         702.543726    34.648646
# 18   1/19/18         803.817635    26.740235
# 19   1/20/18         861.069356    24.836109

# %%
# shape of data
data.shape
# Out:
# (1461, 3)

# %%
# check data column
data.columns
# Out:
# Index(['timestamp', 'energy_production', 'temperature'], dtype='object')

# %%
# check data types
data.dtypes
# Out:
# timestamp             object
# energy_production    float64
# temperature          float64
# dtype: object

# %%
# check the null value of the data
data.isna().sum()
# Out:
# timestamp            0
# energy_production    0
# temperature          0
# dtype: int64

# %%
# summary of data
data.describe()
# Out:
#        energy_production  temperature
# count        1461.000000  1461.000000
# mean          635.281502    19.767968
# std           309.170177     8.624864
# min             1.043564     0.133039
# 25%           381.193804    13.084763
# 50%           704.001963    19.693258
# 75%           914.358525    26.472137
# max          1095.879229    47.923447

# %% [markdown]
# Matplotlib and Seaborn

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
# LINEDATA
# random data
x = np.linspace(1,10,1000)

# plot data
plt.plot(x, np.cos(x), label="Cosine")

# %%
# sample dataframe
dataFrame = pd.DataFrame([
    [1,2],
    [3,4],
    [8,7],
    [6,5],
    [3,5],
    [2,7],
])

dataFrame.plot(kind="bar", stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# SEABORN

# %%
import seaborn as sns 
sns.set()

# %%
#  create randomdata
dataRand0 = np.random.multivariate_normal([0,0],[[5,2],[2,2]], size=2000)
dataRand1 = pd.DataFrame(dataRand0, columns=['x', 'y'])

# %%
# Plot Density
for col in 'xy':
    sns.kdeplot(dataRand1[col], shade=True)

# %%
for col in 'xy':
    sns.distplot(dataRand1[col], kde=False)

# %%
for col in 'xy':
    sns.distplot(dataRand1[col])
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Pair Plot
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue="species", height=2.5)

# %% [markdown]
# SCIKIT-LEARN

# %%
import sklearn

# %%
data.isnull().sum()
# Out:
# timestamp            0
# energy_production    0
# temperature          0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
# impute_weight = SimpleImputer()

# %% [markdown]
# Statsmodel

# %%
import statsmodels

# %%
import statsmodels.api as sm 
from sklearn import datasets

# %%
# loda data of Boston
data = datasets.load_boston()
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
# Create the DataFrame
feature = pd.DataFrame(data.data, columns=data.feature_names)

# %%
feature.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# Separate the target variabel
target = pd.DataFrame(data.target, columns=["MEDV"])

# %%
target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
# Create linear regression 
# define x and y
x = feature
y = target["MEDV"]

# %%
# Build a model
model = sm.OLS(y,x).fit()

# %%
# Make prediction
prediction = model.predict(x)

# %%
# Summary the model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              891.3
# Date:                Fri, 07 Feb 2025   Prob (F-statistic):                        0.00
# Time:                        09:38:34   Log-Likelihood:                         -1523.8
# No. Observations:                 506   AIC:                                      3074.
# Df Residuals:                     493   BIC:                                      3128.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
